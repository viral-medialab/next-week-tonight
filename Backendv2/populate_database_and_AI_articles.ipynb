# %%
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[16], line 3
#       1 from generate_database import *
#       2 from query_utils import *
# ----> 3 from database_utils import clear_all_expired_articles
#       5 clear_all_expired_articles()
#
# ImportError: cannot import name 'clear_all_expired_articles' from 'database_utils' (/Users/allenbaranov/Desktop/2024 IAP UROP 2nd Attempt/Working directory/next-week-tonight/Backendv2/database_utils.py)
