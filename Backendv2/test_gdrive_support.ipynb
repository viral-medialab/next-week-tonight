# %%
import requests
import fitz  # PyMuPDF

def download_and_read_pdf(file_id, destination):
    # Download part
    URL = "https://drive.google.com/uc?export=download"
    session = requests.Session()
    response = session.get(URL, params={'id': file_id}, stream=True)
    token = get_confirm_token(response)
    if token:
        params = {'id': file_id, 'confirm': token}
        response = session.get(URL, params=params, stream=True)
    save_response_content(response, destination)
    
    # Reading part
    text = read_pdf_text(destination)
    return text

def get_confirm_token(response):
    for key, value in response.cookies.items():
        if key.startswith('download_warning'):
            return value
    return None

def save_response_content(response, destination):
    CHUNK_SIZE = 32768
    with open(destination, "wb") as f:
        for chunk in response.iter_content(CHUNK_SIZE):
            if chunk:
                f.write(chunk)

def read_pdf_text(path):
    text = ''
    with fitz.open(path) as doc:
        for page in doc:
            text += page.get_text()
    return text

# %%
def read_pdf_from_url(file_id):
    URL = "https://drive.google.com/uc?export=download"
    session = requests.Session()
    response = session.get(URL, params={'id': file_id}, stream=True)
    token = get_confirm_token(response)
    if token:
        params = {'id': file_id, 'confirm': token}
        response = session.get(URL, params=params, stream=True)

    # Directly use the response content with fitz.open
    pdf_bytes = response.content
    text = read_pdf_text(pdf_bytes)
    return text

def get_confirm_token(response):
    for key, value in response.cookies.items():
        if key.startswith('download_warning'):
            return value
    return None

def read_pdf_text(pdf_bytes):
    text = ''
    # Directly pass the bytes to fitz.open
    with fitz.open(stream=pdf_bytes, filetype="pdf") as doc:
        for page in doc:
            text += page.get_text()
    return text

# %%
file_id = '1PZLdGojG8zeJGfh3WYGDJtaPSBK7dj3p' # Replace YOUR_FILE_ID_HERE with the actual file ID
destination = 'test_pdf.pdf' # Replace YOUR_DESTINATION_PATH_HERE with the path where you want to save the PDF
pdf_text = read_pdf_from_url(file_id)
print(pdf_text)
# Out:
# Centralized & standardized data
# governance and management
# Statistical and actionable insights
# Predictions about future outcomes
# Monetize your data to drive higher
# revenue and C-SAT with our suite of
# Data & Analytics Solutions.
# Coforge BPS’s suite of Data & Analytics Solutions can help organizations drive revenue, monetize data, reduce cost,
# avoid risk and enhance customer engagement with:
# Data & Analytics Solutions
# Data Science
# (AI & ML)
# Data Analytics &
# Predictions
# Data Management &
# Governance
# Data Engineering &
# Technology Adoption
# Our Data & Analytics Solutions incorporate:
# Strong financial services domain
# expertise
# Customized solutions for financial
# services industry
# Support end to end data journey from
# data management to analytics
# Customized delivery model for
# optimal results
# Business Value
# Centralize and standardize data with Data Management
# & Governance
# Obtain future insights with Data Analytics & Predictions
# Get statistics and actionable insights to make
# key business decisions with Data Science
# Transform raw data into useful information with
# Data Engineering & Technology Adoption
# Customized Operating Model
#     Mix of onshore - offshore model to deliver optimal results
#     Flexible delivery teams
#     Agile methodology aligned to customer data program
# Financial Service Domain Expertise
#     19+ years of expertise in providing transformational
#     solutions to the U.S. financial services industry
#     100+ financial services customers including 4 of the top
#     25 U.S. banks
# Core Capabilities
# Data Science ( AI & ML )
#     Pattern Recognition| Product recommendation
#     Statistical computing
#     Fraud Detection
#     Customer Analytics
#     Risk Analytics
#     Operation Analytics
#     Price Optimization
#     Credit Risk Modeling
#     Strategy  Decision Making
#     Campaign Analytics
#     Behavior Analytics
#     Propensity Model
#     Time series Analysis
#     Cluster & Regression Analysis
# Data Management & Governance
#     Enterprise Data Model
#     Data Warehouse & Mgt.
#     Master Data Management (MDM)
#     Data Integration
#     Data Migration
#     Data Quality Rule Conceptualization
#     Rule Testing & Binding
#     Issue Management Performance Management
#     Taxonomies & Namespace
#     Data Domains Metadata Management
#     Data Policies
#     Data Owner
#     Data Management SLA
# Data Analytics & Predictions
#     Data Visualization - Dashboard & Scorecard
#     Data Modeling | Data bQuality & Health Reports
#     Data Insights & Monetization
#     Descriptive & Predictive Analytics
#     What-if Scenarios
#         Self Service BI
#         Survival & Churn Analysis
# Data Engineering & Technology Adoption
#     Data Lake
#     Data Virtualization
#     Cloud DWH | Chabot's
#     Real-time Conversation AI
#     NLP / Unstructured|  NoSQL
#     IOT
# Delivered 99.5% + data completeness in
# master data de-duplication of
# 1.2M customer records
# Read Case Study
# 30% improvement in data quality
# in several lines of business
# for a Bank
# Read Case Study
# Key Features
# Case Study
# End to End Data Journey
#     End to end data journey from Data Management to
#     Data Analytics
#     Expertise in leading data quality & analytics tools –
#     Collabra, Information Analyzer, Tableau, Sas
#     Experience in supporting Risk & Regulatory compliance
#     related projects including FATCA, AML–CCAR etc.
# About Coforge Business Process Solutions
# Transformation
# - 12 digital platform solutions
# - 600+ business processes
# Business Growth
# Deep domain expertise with over
# 20+ years of industry experience
# Flawless execution
# - 100% commitment to SLAs
# - 99% transaction accuracy
# Effective business outcomes
# supported by Digital Platforms,
# Intelligent Automation, RegTech,
# Data & Analytics, & Omnichannel
# Customer Service
# Strong compliance
# 100% adherence to regulatory
# and business requirements
# Scalability
# - 21,000 professionals
# - 7,000+ dedicated to BPS
# - 0.5B transactions annually
# Coforge is a global digital services and solutions provider, that enables its clients to transform at the intersect of
# domain expertise and emerging technologies to achieve real-world business impact. Coforge leads with its product
# engineering approach and leverages Cloud, Data, Integration and Automation technologies to transform client
# businesses into intelligent, high growth enterprises.
# Coforge Business Process Solutions (Coforge BPS) offers services as well as  digital platform solutions to its clients
# in multiple industries, including the financial services industry. Coforge BPS customers include 5 of the Top 25 U.S.
# Banks, Top 10 Lenders, Top 10 Insurance intermediaries and Fortune 500 Companies.
# We help organizations deliver:
# Our optimal blend of people, process, and digital solutions across
# the business value chain has helped drive tangible outcomes for
# our clients, their customers and partners.
# Banking &
# Financial Services
# Insurance
# Mortgage, Title Insurance
# & Property Tax
# Travel, Transport
# & Hospitality
# https://www.coforge.com/bps/
# CoforgeBPS@coforge.com
# Click here to follow us on:
# Pre-Underwriting Support Solution
# LoanAccel
# TM
# Real Estate Tax
# Servicing Platform
# Property Title Search platform
# Property Tax Platform
# An enterprise-wide automated platform
# for QC and Regulatory Compliance

# %%
from google.oauth2.service_account import Credentials
from googleapiclient.discovery import build
from googleapiclient.http import MediaIoBaseUpload
from io import BytesIO

# Convert the string to bytes and prepare it as a file-like object
file_stream = BytesIO(pdf_text.encode())

# Path to your service account key file
SERVICE_ACCOUNT_FILE = 'bold-circuit-392015-118933d56a23.json'
SCOPES = ['https://www.googleapis.com/auth/drive']

credentials = Credentials.from_service_account_file(
        SERVICE_ACCOUNT_FILE, scopes=SCOPES)

service = build('drive', 'v3', credentials=credentials)

folder_id = '1ylDka56ebKOnGMgiB9UMBvB6UzHfHM6T'  # Replace with the actual folder ID

file_metadata = {
    'name': 'test_pdf.txt',
    'parents': [folder_id]
}

# Create the media file upload object and specify the mimetype
media = MediaIoBaseUpload(file_stream, mimetype='text/plain', resumable=True)

# Upload the file
file = service.files().create(body=file_metadata, media_body=media, fields='id').execute()

print('File ID: %s' % file.get('id'))
# Out:
# File ID: 1SgZyQ0iJDOoDbo5zkjou_6YPJ8VGb8Gn

# %%
from database_utils import *
from openai_utils import get_embedding

def save_pdf_to_DB(file_name, id, text):
    client, db, collection = connect_to_mongodb()
    doc = {'name': file_name, 'id': id, 'filetype': 'pdf', 'semantic_embedding': get_embedding(text), 'topic': 'CoForge'}
    collection.insert_one(doc)



def get_pdf_contents_from_DB(file_name):
    client, db, collection = connect_to_mongodb()
    doc = collection.find_one({'name': file_name})
    if not doc:
        return None
    doc_id = doc['id']
    return read_pdf_from_url(doc_id)


connect_to_mongodb()
# Out:
# Pinged your deployment. You successfully connected to MongoDB!
# (MongoClient(host=['ac-ujp5wzn-shard-00-02.h8gtitv.mongodb.net:27017', 'ac-ujp5wzn-shard-00-01.h8gtitv.mongodb.net:27017', 'ac-ujp5wzn-shard-00-00.h8gtitv.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, authsource='admin', replicaset='atlas-pvy4a8-shard-0', ssl=True),
#  Database(MongoClient(host=['ac-ujp5wzn-shard-00-02.h8gtitv.mongodb.net:27017', 'ac-ujp5wzn-shard-00-01.h8gtitv.mongodb.net:27017', 'ac-ujp5wzn-shard-00-00.h8gtitv.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, authsource='admin', replicaset='atlas-pvy4a8-shard-0', ssl=True), 'news'),
#  Collection(Database(MongoClient(host=['ac-ujp5wzn-shard-00-02.h8gtitv.mongodb.net:27017', 'ac-ujp5wzn-shard-00-01.h8gtitv.mongodb.net:27017', 'ac-ujp5wzn-shard-00-00.h8gtitv.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, authsource='admin', replicaset='atlas-pvy4a8-shard-0', ssl=True), 'news'), 'articles'))

# %%
#save_pdf_to_DB('test_pdf.pdf', file_id, pdf_text)#file.get('id'), pdf_text)
get_pdf_contents_from_DB('test_pdf.pdf')
# Out:
# Pinged your deployment. You successfully connected to MongoDB!
# "Centralized & standardized data \ngovernance and management\nStatistical and actionable insights\nPredictions about future outcomes\nMonetize your data to drive higher \nrevenue and C-SAT with our suite of \nData & Analytics Solutions.\nCoforge BPS’s suite of Data & Analytics Solutions can help organizations drive revenue, monetize data, reduce cost, \navoid risk and enhance customer engagement with:\nData & Analytics Solutions\nData Science \n(AI & ML)\nData Analytics & \nPredictions\nData Management & \nGovernance\nData Engineering & \nTechnology Adoption\nOur Data & Analytics Solutions incorporate:\nStrong financial services domain \nexpertise\nCustomized solutions for financial \nservices industry\nSupport end to end data journey from \ndata management to analytics\nCustomized delivery model for\noptimal results\nBusiness Value\nCentralize and standardize data with Data Management \n& Governance\nObtain future insights with Data Analytics & Predictions\nGet statistics and actionable insights to make \nkey business decisions with Data Science\nTransform raw data into useful information with \nData Engineering & Technology Adoption\nCustomized Operating Model\n    Mix of onshore - offshore model to deliver optimal results\n    Flexible delivery teams\n    Agile methodology aligned to customer data program\nFinancial Service Domain Expertise\n    19+ years of expertise in providing transformational \n    solutions to the U.S. financial services industry\n    100+ financial services customers including 4 of the top \n    25 U.S. banks\nCore Capabilities\nData Science ( AI & ML )\n    Pattern Recognition| Product recommendation\n    Statistical computing\n    Fraud Detection\n    Customer Analytics\n    Risk Analytics\n    Operation Analytics\n    Price Optimization\n    Credit Risk Modeling\n    Strategy  Decision Making\n    Campaign Analytics\n    Behavior Analytics\n    Propensity Model\n    Time series Analysis\n    Cluster & Regression Analysis\nData Management & Governance\n    Enterprise Data Model\n    Data Warehouse & Mgt.\n    Master Data Management (MDM)\n    Data Integration\n    Data Migration\n    Data Quality Rule Conceptualization\n    Rule Testing & Binding\n    Issue Management Performance Management\n    Taxonomies & Namespace\n    Data Domains Metadata Management\n    Data Policies\n    Data Owner\n    Data Management SLA\nData Analytics & Predictions\n    Data Visualization - Dashboard & Scorecard\n    Data Modeling | Data bQuality & Health Reports\n    Data Insights & Monetization\n    Descriptive & Predictive Analytics\n    What-if Scenarios\n        Self Service BI\n        Survival & Churn Analysis\nData Engineering & Technology Adoption\n    Data Lake\n    Data Virtualization\n    Cloud DWH | Chabot's\n    Real-time Conversation AI\n    NLP / Unstructured|  NoSQL\n    IOT\nDelivered 99.5% + data completeness in \nmaster data de-duplication of \n1.2M customer records\nRead Case Study\n30% improvement in data quality \nin several lines of business \nfor a Bank\nRead Case Study\nKey Features\nCase Study\nEnd to End Data Journey \n    End to end data journey from Data Management to \n    Data Analytics \n    Expertise in leading data quality & analytics tools – \n    Collabra, Information Analyzer, Tableau, Sas\n    Experience in supporting Risk & Regulatory compliance \n    related projects including FATCA, AML–CCAR etc.\nAbout Coforge Business Process Solutions\nTransformation\n- 12 digital platform solutions \n- 600+ business processes\nBusiness Growth\nDeep domain expertise with over \n20+ years of industry experience\nFlawless execution\n- 100% commitment to SLAs \n- 99% transaction accuracy\nEffective business outcomes \nsupported by Digital Platforms, \nIntelligent Automation, RegTech, \nData & Analytics, & Omnichannel \nCustomer Service\nStrong compliance\n100% adherence to regulatory\nand business requirements\nScalability\n- 21,000 professionals \n- 7,000+ dedicated to BPS\n- 0.5B transactions  ...

# %%
get_pdf_contents_from_DB('test_pdf.pdf', 'test_retrieve_text.txt')
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
from database_utils import *
client, db, collection = connect_to_mongodb()
doc = collection.delete_one({'name': 'test_pdf.pdf'})
doc2 = collection.find_one({'name': 'test_pdf.pdf'})
print(doc2)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!
# None
